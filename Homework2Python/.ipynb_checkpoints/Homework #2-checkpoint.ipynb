# %%
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
import pandas as pd 
df = pd.read_csv('FINAL_FROM_DF.csv')
df
# Out:
#             SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0        20MICRONS     EQ     37.80     37.80     36.15     36.85     37.40
# 1       3IINFOTECH     EQ      4.10      4.85      4.00      4.55      4.65
# 2          3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70  13300.00
# 3          63MOONS     EQ     61.00     61.90     60.35     61.00     61.10
# 4          8KMILES     EQ    546.10    548.00    535.00    537.45    535.20
# ...            ...    ...       ...       ...       ...       ...       ...
# 846399        ZOTA     SM    221.00    221.00    214.00    217.00    217.00
# 846400       ZUARI     EQ    562.00    562.00    549.55    550.80    552.00
# 846401   ZUARIGLOB     EQ    255.50    258.40    252.50    253.25    253.00
# 846402   ZYDUSWELL     EQ   1038.00   1068.00   1033.00   1043.20   1035.00
# 846403       ZYLOG     EQ      4.30      5.15      4.30      4.65      4.60
#
# ...

# %%
df.shape
# Out:
# (846404, 13)

# %%
df.head(15)
# Out:
#         SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0    20MICRONS     EQ     37.80     37.80     36.15     36.85     37.40
# 1   3IINFOTECH     EQ      4.10      4.85      4.00      4.55      4.65
# 2      3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70  13300.00
# 3      63MOONS     EQ     61.00     61.90     60.35     61.00     61.10
# 4      8KMILES     EQ    546.10    548.00    535.00    537.45    535.20
# 5     A2ZINFRA     EQ     41.30     43.00     41.25     42.00     41.90
# 6   AARTIDRUGS     EQ    539.90    539.90    520.00    521.85    522.20
# 7     AARTIIND     EQ    890.95    894.90    876.90    891.30    890.00
# 8    AARVEEDEN     EQ     58.20     61.20     57.00     59.50     59.80
# 9         ABAN     EQ    183.00    184.65    180.80    182.10    181.90
# 10         ABB     EQ   1444.00   1459.70   1424.00   1452.00   1452.50
# 11  ABBOTINDIA     EQ   4300.00   4305.00   4230.00   4236.10   4236.25
# ...

# %%
df['TIMESTAMP'] = pd.to_datetime(df['TIMESTAMP'])
type(df['TIMESTAMP'][0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
#Here I add a column which includes the day of the week 
df['day of the week'] = df['TIMESTAMP'].dt.weekday
df.head(15)
# Out:
#         SYMBOL SERIES      OPEN      HIGH       LOW     CLOSE      LAST  \
# 0    20MICRONS     EQ     37.80     37.80     36.15     36.85     37.40
# 1   3IINFOTECH     EQ      4.10      4.85      4.00      4.55      4.65
# 2      3MINDIA     EQ  13425.15  13469.55  12920.00  13266.70  13300.00
# 3      63MOONS     EQ     61.00     61.90     60.35     61.00     61.10
# 4      8KMILES     EQ    546.10    548.00    535.00    537.45    535.20
# 5     A2ZINFRA     EQ     41.30     43.00     41.25     42.00     41.90
# 6   AARTIDRUGS     EQ    539.90    539.90    520.00    521.85    522.20
# 7     AARTIIND     EQ    890.95    894.90    876.90    891.30    890.00
# 8    AARVEEDEN     EQ     58.20     61.20     57.00     59.50     59.80
# 9         ABAN     EQ    183.00    184.65    180.80    182.10    181.90
# 10         ABB     EQ   1444.00   1459.70   1424.00   1452.00   1452.50
# 11  ABBOTINDIA     EQ   4300.00   4305.00   4230.00   4236.10   4236.25
# ...

# %%
df.corr()
# Out:
#                  OPEN      HIGH       LOW     CLOSE      LAST  PREVCLOSE  \
# OPEN         1.000000  0.999887  0.999906  0.999836  0.999743   0.999164
# HIGH         0.999887  1.000000  0.999818  0.999917  0.999830   0.999111
# LOW          0.999906  0.999818  1.000000  0.999902  0.999808   0.999081
# CLOSE        0.999836  0.999917  0.999902  1.000000  0.999912   0.999061
# LAST         0.999743  0.999830  0.999808  0.999912  1.000000   0.998969
# PREVCLOSE    0.999164  0.999111  0.999081  0.999061  0.998969   1.000000
# TOTTRDQTY   -0.031836 -0.031754 -0.031861 -0.031768 -0.031744  -0.031874
# TOTTRDVAL    0.060235  0.060912  0.059863  0.060530  0.060451   0.060044
# TOTALTRADES  0.022101  0.022765  0.021678  0.022334  0.022429   0.022086
#
#              TOTTRDQTY  TOTTRDVAL  TOTALTRADES
# OPEN         -0.031836   0.060235     0.022101
# HIGH         -0.031754   0.060912     0.022765
# LOW          -0.031861   0.059863     0.021678
# CLOSE        -0.031768   0.060530     0.022334
# ...

# %%
df.corr()['LAST']
# Out:
# OPEN           0.999743
# HIGH           0.999830
# LOW            0.999808
# CLOSE          0.999912
# LAST           1.000000
# PREVCLOSE      0.998969
# TOTTRDQTY     -0.031744
# TOTTRDVAL      0.060451
# TOTALTRADES    0.022429
# Name: LAST, dtype: float64

# %%
# According to the correlation seen on the previous cell I find that OPEN and LAST are highly correlated
#As you can see from the boxplots they do seem to have a strong correlation. 

fig,ax = plt.subplots(figsize = (20,8))
ax.set(yscale = 'log')
df[['OPEN', 'HIGH']].boxplot()
